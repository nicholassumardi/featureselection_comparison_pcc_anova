# %% [markdown]
# # Feature Selection ANOVA F-TEST on PUBG Dataset

# %% [markdown]
# ## Import Library

# %%
import math
import cmath
import sys
import traceback
import pandas as pd
import numpy as np
import seaborn as sns
import scipy as sp
from scipy import stats
from scipy.stats import t
from sklearn import model_selection

# %%
data = pd.read_csv("D:\PROPOSAL SKRIPSI\DATASET\pubg-final.csv")
df = pd.DataFrame(data)


df.style
# Out:
# <style  type="text/css" >
# </style><table id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Bullet Type</th>        <th class="col_heading level0 col1" >Damage</th>        <th class="col_heading level0 col2" >Magazine Capacity</th>        <th class="col_heading level0 col3" >Range</th>        <th class="col_heading level0 col4" >Bullet Speed</th>        <th class="col_heading level0 col5" >Rate of Fire</th>        <th class="col_heading level0 col6" >Shots to Kill (Chest)</th>        <th class="col_heading level0 col7" >Shots to Kill (Head)</th>        <th class="col_heading level0 col8" >Damage Per Second</th>        <th class="col_heading level0 col9" >BDMG_0</th>        <th class="col_heading level0 col10" >BDMG_1</th>        <th class="col_heading level0 col11" >BDMG_2</th>        <th class="col_heading level0 col12" >BDMG_3</th>        <th class="col_heading level0 col13" >HDMG_0</th>        <th class="col_heading level0 col14" >HDMG_1</th>        <th class="col_heading level0 col15" >HDMG_2</th>        <th class="col_heading level0 col16" >HDMG_3</th>        <th class="col_heading level0 col17" >Results</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col0" class="data row0 col0" >7.620000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col1" class="data row0 col1" >49</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col2" class="data row0 col2" >30</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col3" class="data row0 col3" >400</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col4" class="data row0 col4" >715</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col5" class="data row0 col5" >0.080000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col6" class="data row0 col6" >4</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col7" class="data row0 col7" >2</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col8" class="data row0 col8" >612.000000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col9" class="data row0 col9" >47.000000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col10" class="data row0 col10" >34.300000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col11" class="data row0 col11" >29.400000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col12" class="data row0 col12" >22.000000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col13" class="data row0 col13" >115.100000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col14" class="data row0 col14" >80.600000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col15" class="data row0 col15" >69.000000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col16" class="data row0 col16" >51.800000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row0_col17" class="data row0 col17" >Assault Rifle</td>
#             </tr>
#             <tr>
#                         <th id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col0" class="data row1 col0" >7.620000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col1" class="data row1 col1" >49</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col2" class="data row1 col2" >30</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col3" class="data row1 col3" >400</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col4" class="data row1 col4" >710</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col5" class="data row1 col5" >0.010000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col6" class="data row1 col6" >4</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col7" class="data row1 col7" >2</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col8" class="data row1 col8" >490.000000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col9" class="data row1 col9" >47.000000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col10" class="data row1 col10" >34.300000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col11" class="data row1 col11" >29.400000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col12" class="data row1 col12" >22.000000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col13" class="data row1 col13" >115.100000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col14" class="data row1 col14" >80.600000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col15" class="data row1 col15" >69.000000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col16" class="data row1 col16" >51.800000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row1_col17" class="data row1 col17" >Assault Rifle</td>
#             </tr>
#             <tr>
#                         <th id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col0" class="data row2 col0" >7.620000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col1" class="data row2 col1" >47</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col2" class="data row2 col2" >30</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col3" class="data row2 col3" >400</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col4" class="data row2 col4" >715</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col5" class="data row2 col5" >0.086000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col6" class="data row2 col6" >4</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col7" class="data row2 col7" >2</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col8" class="data row2 col8" >547.000000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col9" class="data row2 col9" >46.000000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col10" class="data row2 col10" >32.900000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col11" class="data row2 col11" >28.200000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col12" class="data row2 col12" >21.100000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col13" class="data row2 col13" >110.400000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col14" class="data row2 col14" >77.300000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col15" class="data row2 col15" >66.200000</td>
#                         <td id="T_4a8fffe6_e831_11ec_80f5_e282d958d1d2row2_col16" class="data row2 col16" >49.700000</td>

# %% [markdown]
# # Mendefinisikan Konstruktor  dan Fungsi untuk Algoritma Perhitungan

# %%
class Anova:
    SS = []
    df = []
    F = []
    pval = []
    threshold = 0.05
    
    def compute_SS(self, groups, values, col_name):
    
        """ Calculate the ANOVA by hand. While you would normally not do that, this function shows
        how the underlying values can be calculated.
        """
        try:
            # The "total sum-square" is the squared deviation from the mean
            ss_total = np.sum((values-values.mean())**2)
          
            
            # Calculate ss_treatment and  ss_error
            (ss_treatments, ss_error) = (0, 0)
            for val, group in groups:
                ss_error += sum((group[col_name] - group[col_name].mean())**2)
               
                ss_treatments += len(group) * (group[col_name].mean() - values.mean())**2
             
            return (ss_treatments, ss_error, ss_total)
          
       
        except Exception as e:
            raise
            
            
    def compute_df(self, groups):
        try:
            df_groups = len(groups)-1
            df_residuals = len(data)-len(groups)
           
        
            return (df_groups, df_residuals)
          
       
        except Exception as e:
            raise
            
            
    def compute_F(self, ss_treatments, ss_error, df_groups, df_residuals):
        try:
            F = (ss_treatments/df_groups) / (ss_error/df_residuals)
            df = stats.f(df_groups,df_residuals)
            p = df.sf(F)
           
             # print(('ANOVA-Results: F = {0}, and p<{1}'.format(F, p)))
            return (F, p)
          
       
        except Exception as e:
            raise
            
            
            
    def ss_df_after_compute(self, np_array_ss, index_name, col_name):
        try:
            df = pd.DataFrame(np_array_ss, index=index_name, columns=col_name)
            return df
        except Exception as e:
            raise 
            
            
    def degreeFreedom_df_after_compute(self, np_array_df, index_name, col_name):
        try:
            df = pd.DataFrame(np_array_df, index=index_name, columns=col_name)
            return df
        except Exception as e:
            raise 
            
            
    def f_pval_df_after_compute(self, np_array_f, index_name, col_name):
        try:
            df = pd.DataFrame(np_array_f, index=index_name, columns=col_name)
            return df
        except Exception as e:
            raise 
            
            
    def drop_features(self, dataset, threshold):
        try:
            col_anova = set()
            anova_dataset = dataset
            for i in range(len(df.columns)-1):
                    if anova_dataset.iloc[-1, i] > threshold : #THRESHOLD CHECK
                        colname = anova_dataset.columns[i]  #NAMA DARI FITUR/ KOLOM
                        col_anova.add(colname)
        
            return col_anova
        except Exception as e:
            raise

# %% [markdown]
# # Mendefinisikan Konstruktor  dan Fungsi untuk Klasifikasi

# %%
class classifier :
    validation_size = 0.60
    seed = 7      
            
    def model(self, drop_features):
        try:
            new_df = pd.DataFrame(data)
            new_df.drop(drop_features, axis=1, inplace=True)
            new_df.to_csv("D:\PROPOSAL SKRIPSI\DATASET NEW\PUBGNEW.csv", index=False)  
           
            
            X = new_df.values[:,:-1]
            Y = new_df.values[:,-1:]
      
            
            np.random.seed(classifier.seed)
            
            X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=classifier.validation_size, random_state=classifier.seed)
            
            return new_df
            #return (X_train, X_test, Y_train, Y_test)
        except Exception as e:
            raise 
            
            
    def KNN(self, X_train, X_test, Y_train, Y_test):
        try:
            from sklearn.neighbors import KNeighborsClassifier
            model_KNN = KNeighborsClassifier(n_neighbors = 5, weights = 'distance', p = 3)
            
            
            
            model_KNN.fit(X_train,Y_train.ravel())
            Y_pred = model_KNN.predict(X_test)
            
            print('1) Confusion Matrix for KNN Model:')
            confusion_mat = pd.crosstab(Y_test.flatten(), Y_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
            from IPython.display import display
            display(confusion_mat)
            
            from sklearn.metrics import classification_report
            cr = classification_report(Y_test, Y_pred, labels=None, target_names=None, sample_weight=None, digits=2)
            print('2) Classification report:\n',cr)
            
            accuracy_train = model_KNN.score(X_train,Y_train)
            accuracy_test = model_KNN.score(X_test,Y_test)
            print('3) Accuracy on train and test datasets:', "%.4f and %.4f" % (accuracy_train, accuracy_test))
           
            
            return (accuracy_train, accuracy_test)
        
        
        
            
        except Exception as e:
            raise 
            
            
    def DecisionTree(self, X_train, X_test, Y_train, Y_test):
        try:
           from sklearn.tree import DecisionTreeClassifier
           model_DT = DecisionTreeClassifier(min_samples_leaf = 3, random_state = classifier.seed)
           
           
           model_DT.fit(X_train,Y_train)
           Y_pred = model_DT.predict(X_test)
            
           print('1) Confusion Matrix for DT Model:')
           confusion_mat = pd.crosstab(Y_test.flatten(), Y_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
           from IPython.display import display
           display(confusion_mat)
            
           from sklearn.metrics import classification_report
           cr = classification_report(Y_test.flatten(), Y_pred, labels=None, target_names=None, sample_weight=None, digits=2)
           print('2) Classification report:\n',cr)
            
           accuracy_train = model_DT.score(X_train,Y_train)
           accuracy_test = model_DT.score(X_test,Y_test)
           print('3) Accuracy on train and test datasets:', "%.4f and %.4f" % (accuracy_train, accuracy_test))
           
           return (accuracy_train, accuracy_test)
       
        
        except Exception as e:
            raise 
            
            
    def SupportVectorMachine(self, X_train, X_test, Y_train, Y_test):
        try:
            from sklearn import svm
            model_SVC = svm.SVC(gamma = 'auto')
            
            
            model_SVC.fit(X_train,Y_train.ravel())
            Y_pred = model_SVC.predict(X_test)
            
            print('1) Confusion Matrix for SVC Model:')
            confusion_mat = pd.crosstab(Y_test.flatten(), Y_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
            from IPython.display import display
            display(confusion_mat)
            
            from sklearn.metrics import classification_report
            cr = classification_report(Y_test, Y_pred, labels=None, target_names=None, sample_weight=None, digits=2)
            print('2) Classification report:\n',cr)
            
            accuracy_train = model_SVC.score(X_train,Y_train)
            accuracy_test = model_SVC.score(X_test,Y_test)
            print('3) Accuracy on train and test datasets:', "%.4f and %.4f" % (accuracy_train, accuracy_test))
            
            return (accuracy_train, accuracy_test)
        
        
        except Exception as e:
            raise 
            
            
    def NaiveBayes(self, X_train, X_test, Y_train, Y_test):
        try:
            from sklearn.naive_bayes import GaussianNB
            model_NB = GaussianNB()
            
            
            model_NB.fit(X_train,Y_train.ravel())
            Y_pred = model_NB.predict(X_test)
            
            print('1) Confusion Matrix for NaiveBayes Model:')
            confusion_mat = pd.crosstab(Y_test.flatten(), Y_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
            from IPython.display import display
            display(confusion_mat)
            
            from sklearn.metrics import classification_report
            cr = classification_report(Y_test, Y_pred, labels=None, target_names=None, sample_weight=None, digits=2)
            print('2) Classification report:\n',cr)
            
            accuracy_train = model_NB.score(X_train,Y_train)
            accuracy_test = model_NB.score(X_test,Y_test)
            print('3) Accuracy on train and test datasets:', "%.4f and %.4f" % (accuracy_train, accuracy_test))
        
            return (accuracy_train, accuracy_test)
        
        
        except Exception as e:
            raise

# %% [markdown]
# # Main Program

# %%
if __name__ == '__main__':
    try:
        for i in range(len(df.columns)-1):
            values = df.iloc[:, i]
        
            category = df.columns[-1:].tolist()
            col_name = df.columns[i]
        
            groups = df.groupby(category)
            
            obj = Anova()
            # PERHITUNGAN SS, df, F, P-VALUE
            SS_coeff = obj.compute_SS(groups, values, col_name)
            df_coeff = obj.compute_df(groups)
            F_coeff = obj.compute_F(SS_coeff[0], SS_coeff[1], df_coeff[0], df_coeff[1])
            
         
            # MEMASUKKAN PERHITUNGAN KEDALAM LIST
            obj.SS.append(SS_coeff)
            obj.df.append(df_coeff)
            obj.F.append(F_coeff)
            
    except Exception as e:
        traceback.print_exc()
        sys.exit(1)

# %% [markdown]
# # MENGUBAH LIST MENJADI NUMPY ARRAY

# %%
np_array_SS = np.array(obj.SS).T
np_array_df = np.array(obj.df).T
np_array_f = np.array(obj.F).T

# %% [markdown]
# # MENGUBAH NUMPY ARRAY MENJADI DATAFRAME

# %%
index_name_SS = ['SS Treatments', 'SS Error', 'SS Totals']
index_name_df = ['df GROUP', 'df RESIDUALS']
index_name_F = ['F', 'P-VAL']
col_name = df.columns.drop('Results')


#MENGUBAH NUMPY ARRAY MENJADI DATAFRAME UNTUK MENYIMPAN HASIL ANOVA
SS_result = obj.ss_df_after_compute(np_array_SS, index_name_SS, col_name)
df_result = obj.degreeFreedom_df_after_compute(np_array_df, index_name_df, col_name)
F_PVAL_result = obj.f_pval_df_after_compute(np_array_f, index_name_F, col_name)

# %%
SS_result.transpose()
# Out:
#                        SS Treatments       SS Error     SS Totals
# Bullet Type             3.535095e+02     294.294534  6.478040e+02
# Damage                  7.818665e+04   17345.240476  9.553189e+04
# Magazine Capacity       1.212991e+04    2462.880952  1.459280e+04
# Range                   3.862162e+06  264966.666667  4.127129e+06
# Bullet Speed            4.196619e+06  587223.690476  4.783843e+06
# Rate of Fire            2.023298e+01       1.581215  2.181420e+01
# Shots to Kill (Chest)   7.249589e+01      71.390476  1.438864e+02
# Shots to Kill (Head)    1.736991e+01      13.811905  3.118182e+01
# Damage Per Second       1.721916e+06  568351.922943  2.290268e+06
# BDMG_0                  1.235543e+05   22254.781786  1.458091e+05
# BDMG_1                  6.048050e+04   10857.781738  7.133828e+04
# BDMG_2                  4.410568e+04    7966.088738  5.207177e+04
# BDMG_3                  2.489463e+04    4453.065310  2.934770e+04
# HDMG_0                  2.012488e+05   50784.891476  2.520337e+05
# HDMG_1                  9.863145e+04   25005.438738  1.236369e+05
# HDMG_2                  7.240477e+04   18354.861476  9.075963e+04
# HDMG_3                  4.069338e+04   10258.982976  5.095237e+04

# %%
df_result.transpose()
# Out:
#                        df GROUP  df RESIDUALS
# Bullet Type                   8            35
# Damage                        8            35
# Magazine Capacity             8            35
# Range                         8            35
# Bullet Speed                  8            35
# Rate of Fire                  8            35
# Shots to Kill (Chest)         8            35
# Shots to Kill (Head)          8            35
# Damage Per Second             8            35
# BDMG_0                        8            35
# BDMG_1                        8            35
# BDMG_2                        8            35
# BDMG_3                        8            35
# HDMG_0                        8            35
# HDMG_1                        8            35
# HDMG_2                        8            35
# HDMG_3                        8            35

# %%
F_PVAL_result
# Out:
#        Bullet Type        Damage  Magazine Capacity         Range  \
# F         5.255293  1.972106e+01       2.154728e+01  6.377014e+01
# P-VAL     0.000232  7.559917e-11       2.198685e-11  1.384207e-18
#
#        Bullet Speed  Rate of Fire  Shots to Kill (Chest)  \
# F      3.126612e+01  5.598182e+01               4.442743
# P-VAL  9.728091e-14  1.128985e-17               0.000874
#
#        Shots to Kill (Head)  Damage Per Second        BDMG_0        BDMG_1  \
# F                  5.502020       1.325478e+01  2.428917e+01  2.436982e+01
# P-VAL              0.000157       1.413784e-08  3.994275e-12  3.808039e-12
#
#              BDMG_2        BDMG_3        HDMG_0        HDMG_1        HDMG_2  \
# F      2.422297e+01  2.445821e+01  1.733711e+01  1.725675e+01  1.725815e+01
# P-VAL  4.154346e-12  3.614410e-12  4.368445e-10  4.649130e-10  4.644097e-10
#
#              HDMG_3
# F      1.735392e+01
# P-VAL  4.312051e-10

# %% [markdown]
# # Drop Fitur

# %%
drop_features = obj.drop_features(F_PVAL_result, obj.threshold)
print(drop_features)
print(len(drop_features))
objClassifier = classifier()
model = objClassifier.model(drop_features)

model.head().transpose().style
# Out:
# set()
# 0
# <style  type="text/css" >
# </style><table id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2level0_row0" class="row_heading level0 row0" >Bullet Type</th>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row0_col0" class="data row0 col0" >7.620000</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row0_col1" class="data row0 col1" >7.620000</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row0_col2" class="data row0 col2" >7.620000</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row0_col3" class="data row0 col3" >7.620000</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row0_col4" class="data row0 col4" >5.560000</td>
#             </tr>
#             <tr>
#                         <th id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2level0_row1" class="row_heading level0 row1" >Damage</th>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row1_col0" class="data row1 col0" >49</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row1_col1" class="data row1 col1" >49</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row1_col2" class="data row1 col2" >47</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row1_col3" class="data row1 col3" >49</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row1_col4" class="data row1 col4" >43</td>
#             </tr>
#             <tr>
#                         <th id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2level0_row2" class="row_heading level0 row2" >Magazine Capacity</th>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row2_col0" class="data row2 col0" >30</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row2_col1" class="data row2 col1" >30</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row2_col2" class="data row2 col2" >30</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row2_col3" class="data row2 col3" >30</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row2_col4" class="data row2 col4" >30</td>
#             </tr>
#             <tr>
#                         <th id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2level0_row3" class="row_heading level0 row3" >Range</th>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row3_col0" class="data row3 col0" >400</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row3_col1" class="data row3 col1" >400</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row3_col2" class="data row3 col2" >400</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row3_col3" class="data row3 col3" >500</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row3_col4" class="data row3 col4" >600</td>
#             </tr>
#             <tr>
#                         <th id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2level0_row4" class="row_heading level0 row4" >Bullet Speed</th>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row4_col0" class="data row4 col0" >715</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row4_col1" class="data row4 col1" >710</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row4_col2" class="data row4 col2" >715</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row4_col3" class="data row4 col3" >715</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row4_col4" class="data row4 col4" >880</td>
#             </tr>
#             <tr>
#                         <th id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2level0_row5" class="row_heading level0 row5" >Rate of Fire</th>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row5_col0" class="data row5 col0" >0.080000</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row5_col1" class="data row5 col1" >0.010000</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row5_col2" class="data row5 col2" >0.086000</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row5_col3" class="data row5 col3" >0.010000</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row5_col4" class="data row5 col4" >0.086000</td>
#             </tr>
#             <tr>
#                         <th id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2level0_row6" class="row_heading level0 row6" >Shots to Kill (Chest)</th>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row6_col0" class="data row6 col0" >4</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row6_col1" class="data row6 col1" >4</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row6_col2" class="data row6 col2" >4</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row6_col3" class="data row6 col3" >4</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row6_col4" class="data row6 col4" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2level0_row7" class="row_heading level0 row7" >Shots to Kill (Head)</th>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row7_col0" class="data row7 col0" >2</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row7_col1" class="data row7 col1" >2</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row7_col2" class="data row7 col2" >2</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row7_col3" class="data row7 col3" >2</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row7_col4" class="data row7 col4" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2level0_row8" class="row_heading level0 row8" >Damage Per Second</th>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row8_col0" class="data row8 col0" >612.000000</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row8_col1" class="data row8 col1" >490.000000</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row8_col2" class="data row8 col2" >547.000000</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row8_col3" class="data row8 col3" >490.000000</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row8_col4" class="data row8 col4" >502.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2level0_row9" class="row_heading level0 row9" >BDMG_0</th>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row9_col0" class="data row9 col0" >47.000000</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row9_col1" class="data row9 col1" >47.000000</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row9_col2" class="data row9 col2" >46.000000</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row9_col3" class="data row9 col3" >49.000000</td>
#                         <td id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2row9_col4" class="data row9 col4" >41.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_c26754c8_e831_11ec_a8e2_e282d958d1d2level0_

# %% [markdown]
# # Hasil Klasifikasi Untuk Setiap Classifier

# %% [markdown]
# ## KNN

# %%
  KNN = objClassifier.KNN(model[0], model[1], model[2], model[3])
# Out:
# 1) Confusion Matrix for KNN Model:
# Predicted                Assault Rifle  Designed Marksman Rifle  Melee  \
# Actual
# Assault Rifle                        5                        0      0
# Designed Marksman Rifle              1                        2      0
# Light Machine Gun                    2                        0      0
# Melee                                0                        0      2
# Other                                0                        0      1
# Pistol                               0                        0      2
# Shotgun                              0                        0      0
# Sniper Rifle                         1                        0      0
# Submachine Gun                       0                        0      0
# All                                  9                        2      5
#
# Predicted                Pistol  Sniper Rifle  Submachine Gun  All
# Actual
# Assault Rifle                 0             0               0    5
# Designed Marksman Rifle       0             0               0    3
# Light Machine Gun             0             0               0    2
# Melee                         0             0               0    2
# Other                         0             0               0    1
# Pistol                        1             0               2    5
# Shotgun                       0             0               2    2
# Sniper Rifle                  0             2               0    3
# Submachine Gun                0             0               4    4
# All                           1             2               8   27
# 2) Classification report:
#                           precision    recall  f1-score   support
#
#           Assault Rifle       0.56      1.00      0.71         5
# Designed Marksman Rifle       1.00      0.67      0.80         3
#       Light Machine Gun       0.00      0.00      0.00         2
#                   Melee       0.40      1.00      0.57         2
#                   Other       0.00      0.00      0.00         1
#                  Pistol       1.00      0.20      0.33         5
#                 Shotgun       0.00      0.00      0.00         2
#            Sniper Rifle       1.00      0.67      0.80         3
#          Submachine Gun       0.50      1.00      0.67         4
#
#                accuracy                           0.59        27
#               macro avg       0.50      0.50      0.43        27
#            weighted avg       0.61      0.59      0.51        27
#
# 3) Accuracy on train and test datasets: 1.0000 and 0.5926
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Decision Tree

# %%
DT = objClassifier.DecisionTree(model[0], model[1], model[2], model[3])
# Out:
# 1) Confusion Matrix for DT Model:
# Predicted                Assault Rifle  Designed Marksman Rifle  Melee  \
# Actual
# Assault Rifle                        2                        0      0
# Designed Marksman Rifle              0                        3      0
# Light Machine Gun                    1                        0      0
# Melee                                0                        0      2
# Other                                0                        0      1
# Pistol                               0                        2      1
# Shotgun                              0                        0      0
# Sniper Rifle                         0                        0      0
# Submachine Gun                       0                        3      0
# All                                  3                        8      4
#
# Predicted                Pistol  Submachine Gun  All
# Actual
# Assault Rifle                 0               3    5
# Designed Marksman Rifle       0               0    3
# Light Machine Gun             0               1    2
# Melee                         0               0    2
# Other                         0               0    1
# Pistol                        2               0    5
# Shotgun                       2               0    2
# Sniper Rifle                  3               0    3
# Submachine Gun                0               1    4
# All                           7               5   27
# 2) Classification report:
#                           precision    recall  f1-score   support
#
#           Assault Rifle       0.67      0.40      0.50         5
# Designed Marksman Rifle       0.38      1.00      0.55         3
#       Light Machine Gun       0.00      0.00      0.00         2
#                   Melee       0.50      1.00      0.67         2
#                   Other       0.00      0.00      0.00         1
#                  Pistol       0.29      0.40      0.33         5
#                 Shotgun       0.00      0.00      0.00         2
#            Sniper Rifle       0.00      0.00      0.00         3
#          Submachine Gun       0.20      0.25      0.22         4
#
#                accuracy                           0.37        27
#               macro avg       0.23      0.34      0.25        27
#            weighted avg       0.28      0.37      0.30        27
#
# 3) Accuracy on train and test datasets: 0.8235 and 0.3704
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Support Vector Machine

# %%
SVM = objClassifier.SupportVectorMachine(model[0], model[1], model[2], model[3])
# Out:
# 1) Confusion Matrix for SVC Model:
# Predicted                Assault Rifle  Melee  All
# Actual
# Assault Rifle                        5      0    5
# Designed Marksman Rifle              3      0    3
# Light Machine Gun                    2      0    2
# Melee                                0      2    2
# Other                                1      0    1
# Pistol                               5      0    5
# Shotgun                              2      0    2
# Sniper Rifle                         3      0    3
# Submachine Gun                       4      0    4
# All                                 25      2   27
# 2) Classification report:
#                           precision    recall  f1-score   support
#
#           Assault Rifle       0.20      1.00      0.33         5
# Designed Marksman Rifle       0.00      0.00      0.00         3
#       Light Machine Gun       0.00      0.00      0.00         2
#                   Melee       1.00      1.00      1.00         2
#                   Other       0.00      0.00      0.00         1
#                  Pistol       0.00      0.00      0.00         5
#                 Shotgun       0.00      0.00      0.00         2
#            Sniper Rifle       0.00      0.00      0.00         3
#          Submachine Gun       0.00      0.00      0.00         4
#
#                accuracy                           0.26        27
#               macro avg       0.13      0.22      0.15        27
#            weighted avg       0.11      0.26      0.14        27
#
# 3) Accuracy on train and test datasets: 1.0000 and 0.2593
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Naive Bayes

# %%
NB = objClassifier.NaiveBayes(model[0], model[1], model[2], model[3])
# Out:
# 1) Confusion Matrix for NaiveBayes Model:
# Predicted                Assault Rifle  Designed Marksman Rifle  Melee  \
# Actual
# Assault Rifle                        5                        0      0
# Designed Marksman Rifle              0                        3      0
# Light Machine Gun                    0                        2      0
# Melee                                0                        0      2
# Other                                0                        0      1
# Pistol                               0                        0      0
# Shotgun                              0                        0      0
# Sniper Rifle                         0                        3      0
# Submachine Gun                       0                        0      0
# All                                  5                        8      3
#
# Predicted                Pistol  Submachine Gun  All
# Actual
# Assault Rifle                 0               0    5
# Designed Marksman Rifle       0               0    3
# Light Machine Gun             0               0    2
# Melee                         0               0    2
# Other                         0               0    1
# Pistol                        3               2    5
# Shotgun                       2               0    2
# Sniper Rifle                  0               0    3
# Submachine Gun                0               4    4
# All                           5               6   27
# 2) Classification report:
#                           precision    recall  f1-score   support
#
#           Assault Rifle       1.00      1.00      1.00         5
# Designed Marksman Rifle       0.38      1.00      0.55         3
#       Light Machine Gun       0.00      0.00      0.00         2
#                   Melee       0.67      1.00      0.80         2
#                   Other       0.00      0.00      0.00         1
#                  Pistol       0.60      0.60      0.60         5
#                 Shotgun       0.00      0.00      0.00         2
#            Sniper Rifle       0.00      0.00      0.00         3
#          Submachine Gun       0.67      1.00      0.80         4
#
#                accuracy                           0.63        27
#               macro avg       0.37      0.51      0.42        27
#            weighted avg       0.49      0.63      0.53        27
#
# 3) Accuracy on train and test datasets: 1.0000 and 0.6296
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
